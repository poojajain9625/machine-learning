# %%
import pandas as pd

# %%
# reading flat file into a pandas dataframe
# market_analysis=pd.read_csv(r'C:\Users\Dell\Desktop\market\Marketing_Analysis.csv', skiprows=2)
market_analysis=pd.read_csv(r'C:\Users\Dell\Desktop\market\Marketing_Analysis.csv', header=2)
market_analysis
# Out:
#        customerid   age  salary  balance   marital                  jobedu  \
# 0               1  58.0  100000     2143   married     management,tertiary
# 1               2  44.0   60000       29    single    technician,secondary
# 2               3  33.0  120000        2   married  entrepreneur,secondary
# 3               4  47.0   20000     1506   married     blue-collar,unknown
# 4               5  33.0       0        1    single         unknown,unknown
# ...           ...   ...     ...      ...       ...                     ...
# 45206       45207  51.0   60000      825   married     technician,tertiary
# 45207       45208  71.0   55000     1729  divorced         retired,primary
# 45208       45209  72.0   55000     5715   married       retired,secondary
# 45209       45210  57.0   20000      668   married   blue-collar,secondary
# 45210       45211  37.0  120000     2971   married  entrepreneur,secondary
#
#       targeted default housing loan    contact  day      month  \
# ...

# %%
# Displaying data
# only top 5 rows
market_analysis.head(5)
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
# 3       no      no     yes   no  unknown    5  may, 2017   92 sec         1
# 4       no      no      no   no  unknown    5  may, 2017  198 sec         1
#
#    pdays  previous poutcome response
# 0     -1         0  unknown       no
# ...

# %%
# only bottom 5 rows
market_analysis.tail(5)
# Out:
#        customerid   age  salary  balance   marital                  jobedu  \
# 45206       45207  51.0   60000      825   married     technician,tertiary
# 45207       45208  71.0   55000     1729  divorced         retired,primary
# 45208       45209  72.0   55000     5715   married       retired,secondary
# 45209       45210  57.0   20000      668   married   blue-collar,secondary
# 45210       45211  37.0  120000     2971   married  entrepreneur,secondary
#
#       targeted default housing loan    contact  day      month  \
# 45206      yes      no      no   no   cellular   17  nov, 2017
# 45207      yes      no      no   no   cellular   17  nov, 2017
# 45208      yes      no      no   no   cellular   17  nov, 2017
# 45209      yes      no      no   no  telephone   17  nov, 2017
# 45210      yes      no      no   no   cellular   17  nov, 2017
#
#                    duration  campaign  pdays  previous poutcome response
# ...

# %%
# 5 random rows. we write n=5 also in all
market_analysis.sample(5)
# Out:
#        customerid   age  salary  balance   marital                jobedu  \
# 42287       42288  24.0    4000      382    single     student,secondary
# 15446       15447  32.0  100000      273   married   management,tertiary
# 23553       23554  34.0   60000        0    single  technician,secondary
# 11100       11101  55.0   55000       31   married     retired,secondary
# 35566       35567  45.0   70000      608  divorced    services,secondary
#
#       targeted default housing loan   contact  day      month  \
# 42287      yes      no      no   no  cellular   13  nov, 2017
# 15446      yes      no     yes  yes  cellular   18  jul, 2017
# 23553      yes      no      no   no  cellular   28  aug, 2017
# 11100      yes      no      no   no   unknown   18  jun, 2017
# 35566      yes      no     yes  yes  cellular    7  may, 2017
#
#                    duration  campaign  pdays  previous poutcome response
# 42287  4.26666666666667 min         2     92         3  failure      yes
# ...

# %%
student_data=pd.DataFrame({
    'name':['payal','pooja','kanha','radha','rahul'],
    'age':[20,20,3,2,17],
    'gender':['female','female','male','female','male'],
    'location':['Haryana','Haryana','Vrindavan','Vrindavan','Delhi'],
    'Percentage':[89,90,99,99,78],
    'standard':[10,10,1,1,9],
})
student_data
# Out:
#     name  age  gender   location  Percentage  standard
# 0  payal   20  female    Haryana          89        10
# 1  pooja   20  female    Haryana          90        10
# 2  kanha    3    male  Vrindavan          99         1
# 3  radha    2  female  Vrindavan          99         1
# 4  rahul   17    male      Delhi          78         9

# %%
# last two rows are deleted
student_data.head(-2)
# Out:
#     name  age  gender   location  Percentage  standard
# 0  payal   20  female    Haryana          89        10
# 1  pooja   20  female    Haryana          90        10
# 2  kanha    3    male  Vrindavan          99         1

# %%
# starting two rows are deleted
student_data.tail(-2)
# Out:
#     name  age  gender   location  Percentage  standard
# 2  kanha    3    male  Vrindavan          99         1
# 3  radha    2  female  Vrindavan          99         1
# 4  rahul   17    male      Delhi          78         9

# %%
# 45211 rows, 19 columns in data
market_analysis.shape
# Out:
# (45211, 19)

# %%
name='hina'
age=14
sub='python'

# output My name is hina, I am 14 years old, and I love Python
print(f'My name is',name, 'I am', age, 'years old, and I love',sub )
# Out:
# My name is hina I am 14 years old, and I love python

# %%
name='hina'
age=14
sub='python'
# f string hum tab use karenge jab hum string ke andar apne variables ko use karna chate hai
# output My name is hina, I am 14 years old, and I love Python
print(f'My name is {name} I am {age} years old, and I love {sub}')
# Out:
# My name is hina I am 14 years old, and I love python

# %%
# output my rows= 45211
x=market_analysis.shape[0]
print('My rows = {x}')
# Out:
# My rows = {x}

# %%
# output my rows= 45211
x=market_analysis.shape[0]
print(f'My rows = {x}')
# Out:
# My rows = 45211

# %%
# rows*column
market_analysis.size
# Out:
# 859009

# %%
# rows
market_analysis.shape[0]
# Out:
# 45211

# %%
# columns
market_analysis.shape[1]
# Out:
# 19

# %%
market_analysis.shape[0]*market_analysis.shape[1]
# Out:
# 859009

# %%
market_analysis.dtypes
# Out:
# customerid      int64
# age           float64
# salary          int64
# balance         int64
# marital        object
# jobedu         object
# targeted       object
# default        object
# housing        object
# loan           object
# contact        object
# day             int64
# month          object
# duration       object
# campaign        int64
# pdays           int64
# previous        int64
# poutcome       object
# response       object
# dtype: object

# %%
market_analysis.response.dtypes
# Out:
# dtype('O')

# %%
market_analysis.customerid.dtypes
# Out:
# dtype('int64')

# %%
# we write datatypes both methods
market_analysis['customerid'].dtypes
# Out:
# dtype('int64')

# %%
# [[]] double square braces we use because more than one datatype we show so we use list because in list we give more data
market_analysis[['customerid','response']].dtypes
# Out:
# customerid     int64
# response      object
# dtype: object

# %%
market_analysis[['jobedu','response']]
# Out:
#                        jobedu response
# 0         management,tertiary       no
# 1        technician,secondary       no
# 2      entrepreneur,secondary       no
# 3         blue-collar,unknown       no
# 4             unknown,unknown       no
# ...                       ...      ...
# 45206     technician,tertiary      yes
# 45207         retired,primary      yes
# 45208       retired,secondary      yes
# 45209   blue-collar,secondary       no
# 45210  entrepreneur,secondary       no
#
# [45211 rows x 2 columns]

# %%
market_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerid  45211 non-null  int64
#  1   age         45191 non-null  float64
#  2   salary      45211 non-null  int64
#  3   balance     45211 non-null  int64
#  4   marital     45211 non-null  object
#  5   jobedu      45211 non-null  object
#  6   targeted    45211 non-null  object
#  7   default     45211 non-null  object
#  8   housing     45211 non-null  object
#  9   loan        45211 non-null  object
#  10  contact     45211 non-null  object
#  11  day         45211 non-null  int64
#  12  month       45161 non-null  object
#  13  duration    45211 non-null  object
#  14  campaign    45211 non-null  int64
#  15  pdays       45211 non-null  int64
#  16  previous    45211 non-null  int64
#  17  poutcome    45211 non-null  object
#  18  response    45181 non-null  object
# ...

# %%
market_analysis.describe()
# Out:
#          customerid           age         salary        balance           day  \
# count  45211.000000  45191.000000   45211.000000   45211.000000  45211.000000
# mean   22606.000000     40.935651   57006.171065    1362.272058     15.806419
# std    13051.435847     10.619198   32085.718415    3044.765829      8.322476
# min        1.000000     18.000000       0.000000   -8019.000000      1.000000
# 25%    11303.500000     33.000000   20000.000000      72.000000      8.000000
# 50%    22606.000000     39.000000   60000.000000     448.000000     16.000000
# 75%    33908.500000     48.000000   70000.000000    1428.000000     21.000000
# max    45211.000000     95.000000  120000.000000  102127.000000     31.000000
#
#            campaign         pdays      previous
# count  45211.000000  45211.000000  45211.000000
# mean       2.763841     40.197828      0.580323
# std        3.098021    100.128746      2.303441
# min        1.000000     -1.000000      0.000000
# ...

# %%
market_analysis.columns
# Out:
# Index(['customerid', 'age', 'salary', 'balance', 'marital', 'jobedu',
#        'targeted', 'default', 'housing', 'loan', 'contact', 'day', 'month',
#        'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'response'],
#       dtype='object')

# %%
import numpy as np
# ar1 it will cange numeric data into decimal(float)
ar1= np.array([1,2,3,1.45])
ar1
# Out:
# array([1.  , 2.  , 3.  , 1.45])

# %%
# ary1 it will change numeric into char
ar1= np.array([1,2,3,'4'])
ar1
# Out:
# array(['1', '2', '3', '4'], dtype='<U11')

# %%
# Dropping an un-necessari column(varaible) but they dont delete beacause it is actual data to modify but we drop that actual data
newdata =market_analysis.drop('balance', axis='columns')
market_analysis.head(3)
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
#
#    pdays  previous poutcome response
# 0     -1         0  unknown       no
# 1     -1         0  unknown       no
# 2     -1         0  unknown       no

# %%
# Drpping an un-necessari column(varaible)
newdata=market_analysis.drop('customerid', axis='columns', inplace=True)
market_analysis.head(3)
# Out:
#     age  salary  balance  marital                  jobedu targeted default  \
# 0  58.0  100000     2143  married     management,tertiary      yes      no
# 1  44.0   60000       29   single    technician,secondary      yes      no
# 2  33.0  120000        2  married  entrepreneur,secondary      yes      no
#
#   housing loan  contact  day      month duration  campaign  pdays  previous  \
# 0     yes   no  unknown    5  may, 2017  261 sec         1     -1         0
# 1     yes   no  unknown    5  may, 2017  151 sec         1     -1         0
# 2     yes  yes  unknown    5  may, 2017   76 sec         1     -1         0
#
#   poutcome response
# 0  unknown       no
# 1  unknown       no
# 2  unknown       no

# %%
market_analysis.isnull().sum()
# Out:
# age         20
# salary       0
# balance      0
# marital      0
# jobedu       0
# targeted     0
# default      0
# housing      0
# loan         0
# contact      0
# day          0
# month       50
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# response    30
# dtype: int64
